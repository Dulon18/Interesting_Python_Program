# %% [markdown]
# <a href="https://colab.research.google.com/github/Dulon18/Interesting_Python_Program/blob/main/Code_as_Task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![codeproblem1.png](data:image/png;base64,...)

# %%
i=int(input())
def rev(i):
    if i>0:
        rev(i-1)
        print(i,end=' ')
rev(i)
def rev2(i):
    if i>1:
        print(i-1,end=' ')
        rev2(i-1)
rev2(i)
# Out:
# 5
# 1 2 3 4 5 4 3 2 1
